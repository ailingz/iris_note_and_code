# %% [markdown]
# Book 1
# Chapter 11 2D and 3D Visualizations
# ### 设置三维图像观察视角

# %%
# 导入 Matplotlib 的绘图模块
import matplotlib.pyplot as plt

# %%
# 创建一个新的图形窗口
fig = plt.figure()

# 在图形窗口中添加一个3D坐标轴子图
ax = fig.add_subplot(projection='3d')

# 设置坐标轴的标签
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

# 设置投影类型为正交投影 orthographic projection
ax.set_proj_type('ortho')

# 设置观察者的仰角为30度，方位角为30度，即改变三维图形的视角
ax.view_init(elev=30, azim=30)

# 设置三个坐标轴的比例一致，使得图形在三个方向上等比例显示
ax.set_box_aspect([1, 1, 1])

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.set_proj_type('persp') # 透视投影
ax.view_init(elev=15, azim=15)
ax.set_box_aspect([1, 1.5, 1])

plt.show()

# %%
# Identify the parameter default values
import inspect
import mpl_toolkits

def get_default_args(func):
    signature = inspect.signature(func)

    return {
        k: v.default
        for k, v in signature.parameters.items()
        if v.default is not inspect.Parameter.empty
    }

get_default_args(mpl_toolkits.mplot3d.axes3d.Axes3D.view_init)
# Out:
# {'elev': None,
#  'azim': None,
#  'roll': None,
#  'vertical_axis': 'z',
#  'share': False}
